# %% [markdown]
# <a href="https://colab.research.google.com/github/20SA1164/Modul-MSIB-/blob/main/Source%20Code%20Self%20Learning%207%20(Latihan%207).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Latihan 1 (menulis file)
#
# Buat folder baru bernama 'latihan'.
# Buat file baru dalam folder 'latihan' bernama 'my favorite quote.txt'.
# Write file tersebut dengan kutipan/quote yang sangat kalian sukai.
# Read file yang sudah kalian write.

# %%
import os

# %%
f = open('/content/Latihan/my favorite quote.txt')

# %%
f = open('/content/Latihan/my favorite quote.txt', 'r+')
f.write("Jangan Patah Semangat")
f.seek(0)
print(f.read())
f.close()
# Out:
# Jangan Patah Semangat

# %% [markdown]
# Latihan 2
#
# Read file CSV dari link ini https://ngodingdata.com/wp-content/uploads/2020/05/titanic.csv kemudian load dalam DataFrame.
#
# Buat DataFrame baru (DataFrame II) yang hanya berisi kolom 'Survived', 'Pclass', dan 'Age' saja.
#
# Ambil seluruh data dari DataFrame II yang Age > 25, kemudian simpan dalam DataFrame baru (DataFrame III).
#
# Simpan DataFrame III di folder 'latihan' dengan nama 'latihan2.csv'.

# %%
c= open('/content/Latihan/titanic.csv')
temp = c.read()
c.close()
print(temp)
# Out:
# PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/5 21171,7.25,,S
# 2,1,1,"Cumings, Mrs. John Bradley (Florence Briggs Thayer)",female,38,1,0,PC 17599,71.2833,C85,C
# 3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,STON/O2. 3101282,7.925,,S
# 4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May Peel)",female,35,1,0,113803,53.1,C123,S
# 5,0,3,"Allen, Mr. William Henry",male,35,0,0,373450,8.05,,S
# 6,0,3,"Moran, Mr. James",male,,0,0,330877,8.4583,,Q
# 7,0,1,"McCarthy, Mr. Timothy J",male,54,0,0,17463,51.8625,E46,S
# 8,0,3,"Palsson, Master. Gosta Leonard",male,2,3,1,349909,21.075,,S
# 9,1,3,"Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)",female,27,0,2,347742,11.1333,,S
# 10,1,2,"Nasser, Mrs. Nicholas (Adele Achem)",female,14,1,0,237736,30.0708,,C
# 11,1,3,"Sandstrom, Miss. Marguerite Rut",female,4,1,1,PP 9549,16.7,G6,S
# 12,1,1,"Bonnell, Miss. Elizabeth",female,58,0,0,113783,26.55,C103,S
# ...

# %%
import pandas as pd

# %%
DataFrame = pd.read_csv('/content/Latihan/titanic.csv')
DataFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(DataFrame)
# Out:
# pandas.core.frame.DataFrame

# %%
DataFrameII = DataFrame[['Survived', 'Pclass','Age']]
DataFrameII
# Out:
#      Survived  Pclass   Age
# 0           0       3  22.0
# 1           1       1  38.0
# 2           1       3  26.0
# 3           1       1  35.0
# 4           0       3  35.0
# ..        ...     ...   ...
# 886         0       2  27.0
# 887         1       1  19.0
# 888         0       3   NaN
# 889         1       1  26.0
# 890         0       3  32.0
#
# [891 rows x 3 columns]

# %%
type(DataFrameII)
# Out:
# pandas.core.frame.DataFrame

# %%
DataFrameIII = DataFrameII[DataFrameII['Age'] > 25]
DataFrameIII
# Out:
#      Survived  Pclass   Age
# 1           1       1  38.0
# 2           1       3  26.0
# 3           1       1  35.0
# 4           0       3  35.0
# 6           0       1  54.0
# ..        ...     ...   ...
# 883         0       2  28.0
# 885         0       3  39.0
# 886         0       2  27.0
# 889         1       1  26.0
# 890         0       3  32.0
#
# [413 rows x 3 columns]

# %%
DataFrameIII.to_csv('/content/Latihan/latihan2.csv')

# %% [markdown]
# Latihan 3
#
# Cari image apapun di internet.
# Read dan tampilkan image.
# Cari tahu ukuran tensor-nya.
# Lakukan operasi aritmatika apapun pada image.
# Tampilkan image hasil operasi aritmatika.
# Simpan image hasil operasi aritmatika dalam folder 'latihan' dengan nama 'latihan3.png'

# %%
image = open('/content/Latihan/hardisk.jpg','rb')
print(image.read())
image.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x01\x00H\x00H\x00\x00\xff\xe1\x00xExif\x00\x00II*\x00\x08\x00\x00\x00\x04\x00\x12\x01\x03\x00\x01\x00\x00\x00\x01\x00\x00\x001\x01\x02\x00\x07\x00\x00\x00>\x00\x00\x00\x12\x02\x03\x00\x02\x00\x00\x00\x01\x00\x01\x00i\x87\x04\x00\x01\x00\x00\x00F\x00\x00\x00\x00\x00\x00\x00Google\x00\x00\x03\x00\x00\x90\x07\x00\x04\x00\x00\x000220\x02\xa0\x04\x00\x01\x00\x00\x00w\x01\x00\x00\x03\xa0\x04\x00\x01\x00\x00\x00,\x01\x00\x00\x00\x00\x00\x00\xff\xee\x00!Adobe\x00d@\x
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img_hardisk = cv2.imread('/content/Latihan/hardisk.jpg')

# %%
cv2_imshow(img_hardisk)
# Out:
# <PIL.Image.Image image mode=RGB size=375x300 at 0x7FC68EBF9350>

# %%
print(img_hardisk)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
print(img_hardisk.shape)
# Out:
# (300, 375, 3)

# %%
edit_hardisk = 0.9 * (img_hardisk + 70)

# %%
cv2_imshow(edit_hardisk)
# Out:
# <PIL.Image.Image image mode=RGB size=375x300 at 0x7FC68EC0A510>

# %% [markdown]
# Latihan 4
#
# Download file dari link berikut https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz kemudian simpan dalam folder 'latihan' dengan nama 'latihan4.tar.gz'
#
# Extract file tersebut kemudan simpan hasil ekstrak di folder 'latihan'.

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Out:
# --2022-09-07 10:16:52--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  46.7MB/s    in 1.7s
#
# 2022-09-07 10:16:53 (46.7 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %%
# !tar -xzvf '/content/Latihan/latihan4.tar.gz'
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# aclImdb/train/unsup/44983_0.txt
# aclImdb/train/unsup/44982_0.txt
# aclImdb/train/unsup/44981_0.txt
# aclImdb/train/unsup/44980_0.txt
# aclImdb/train/unsup/44979_0.txt
# aclImdb/train/unsup/44978_0.txt
# aclImdb/train/unsup/44977_0.txt
# aclImdb/train/unsup/44976_0.txt
# aclImdb/train/unsup/44975_0.txt
# aclImdb/train/unsup/44974_0.txt
# aclImdb/train/unsup/44973_0.txt
# aclImdb/train/unsup/44972_0.txt
# aclImdb/train/unsup/44971_0.txt
# aclImdb/train/unsup/44970_0.txt
# aclImdb/train/unsup/44969_0.txt
# aclImdb/train/unsup/44968_0.txt
# aclImdb/train/unsup/44967_0.txt
# aclImdb/train/unsup/44966_0.txt
# aclImdb/train/unsup/44965_0.txt
# aclImdb/train/unsup/44964_0.txt
# aclImdb/train/unsup/44963_0.txt
# aclImdb/train/unsup/44962_0.txt
# aclImdb/train/unsup/44961_0.txt
# aclImdb/train/unsup/44960_0.txt
# aclImdb/train/unsup/44959_0.txt
# aclImdb/train/unsup/44958_0.txt
# aclImdb/train/unsup/44957_0.txt
# ...
